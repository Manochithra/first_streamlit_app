# %% [markdown]
# <a href="https://colab.research.google.com/github/Manochithra/first_streamlit_app/blob/main/Day1_1182026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Intro to Python

# %%
print("Welcome ,Mano")
# Out:
# Welcome ,Mano

# %%
print(5+3)
# Out:
# 8

# %%
len("mano")
# Out:
# 4

# %%
print("Sum of 5+5 is ",5+5)
# Out:
# Sum of 5+5 is  10
